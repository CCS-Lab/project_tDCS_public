# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# '/home/kimhj9502/Project/project_tDCS/analysis/modeling'

# %%
corr = pd.read_csv('for_corr.csv')

# %%
corr = corr.iloc[:, 2:]

# %%
plt.rcParams['figure.figsize'] = [15, 12]

# %%
sns.heatmap(corr.corr(), vmin = -1, vmax = 1)

# %%
corr.corr()
# Out:
#                        RBI       PBS       PPB  behav_PavAll_del  \
# RBI               1.000000  0.854019  0.935978          0.955730
# PBS               0.854019  1.000000  0.982498          0.959928
# PPB               0.935978  0.982498  1.000000          0.991798
# behav_PavAll_del  0.955730  0.959928  0.991798          1.000000
# behav_PavRew_del  0.868655  0.973141  0.969563          0.940056
# behav_PavPun_del  0.194317 -0.098160  0.003148          0.112512
# xi_del            0.306676  0.180610  0.232027          0.262864
# ep_del           -0.105036  0.004498 -0.034564         -0.033546
# epRew_del        -0.149641 -0.327510 -0.275211         -0.244119
# b_del            -0.136091 -0.025721 -0.066133         -0.085099
# pi_del            0.201124  0.198416  0.206284          0.226500
# rhoRew_del        0.114397  0.122774  0.124043          0.136822
# rhoPun_del       -0.227849 -0.178633 -0.202465         -0.191705
# ...
